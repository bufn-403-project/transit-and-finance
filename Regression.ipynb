# %%
import geopandas as gpd
import folium
from folium.plugins import MarkerCluster
import pandas as pd
import branca.colormap as cm
from shapely.geometry import Point
from shapely.geometry import mapping
from shapely.geometry import shape
from shapely import wkt
import numpy as np
import json
import statsmodels.api as sm

# %%
census_groups_df = './final/census_features.csv'
df_census = pd.read_csv(census_groups_df)
df_census.head()
# Out:
#    Unnamed: 0                                 center  area_m2  avg_stars  \
# 0           0    39.96876598164982,-75.1997268790072   161887        NaN
# 1           1    39.96655556342398,-75.2004472970602   103778        NaN
# 2           2   39.96430097635668,-75.18964523537966    43724        NaN
# 3           3     39.9753665759928,-75.2113493640991   108966        NaN
# 4           4  39.972428220268384,-75.20517069878659   142244        NaN
#
#    choice  no_truck_length  distance_pool  avg_housing_price  \
# 0    True         0.000000       0.001575             3808.0
# 1    True         0.000000       0.000000             6752.0
# 2    True         0.000000       0.008896             7824.0
# 3   False         0.000000       0.001422             5920.0
# 4   False      2146.077336       0.005254             4064.0
#
#    foreclosure_count  foreclosure_over_area
# 0                  0               0.000000
# 1                  4               0.000039
# 2                  0               0.000000
# 3                  2               0.000018
# 4                  3               0.000021

# %%
iso_df = './final/iso_features.csv'
iso_df = pd.read_csv(iso_df)
iso_df.head()
# Out:
#    Unnamed: 0               isochrone                               center  \
# 0           0   421010108001-600-foot  39.96876598164982,-75.1997268790072
# 1           1  421010108001-1200-foot  39.96876598164982,-75.1997268790072
# 2           2  421010108001-1800-foot  39.96876598164982,-75.1997268790072
# 3           3    421010108001-600-car  39.96876598164982,-75.1997268790072
# 4           4   421010108001-1200-car  39.96876598164982,-75.1997268790072
#
#         area_m2  avg_stars  choice  no_truck_length  distance_pool  \
# 0  1.545242e+06   3.708333    True      1458.387879            0.0
# 1  7.552386e+06   3.519802    True      4245.550548            0.0
# 2  1.737010e+07   3.473648    True      8506.445760            0.0
# 3  1.988733e+08   3.681063    True    209322.298891            0.0
# 4  1.108233e+09   3.642439    True    835668.097031            0.0
#
#    avg_housing_price  foreclosure_count  foreclosure_over_area
# 0             5719.0                 13               0.000008
# 1             5152.0                 53               0.000007
# 2             5584.0                 80               0.000005
# 3             8960.0               1176               0.000006
# 4            11168.0               2706               0.000002

# %%
features = ['area_m2', 'avg_stars', 'choice', 'no_truck_length', 'distance_pool', 'foreclosure_count', 'foreclosure_over_area']
target = 'avg_housing_price'

# %%
def run_regression(df, features, target):
    df_clean = df.dropna(subset=features + [target])
    X = df_clean[features].copy()
    for col in ['choice', 'no_truck_length']:
        if col in X.columns and X[col].dtype == bool:
            X[col] = X[col].astype(int)
    X = sm.add_constant(X)
    y = df_clean[target]
    model = sm.OLS(y, X).fit()
    return model

# %%
census_model = run_regression(df_census, features, target)
print(census_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      avg_housing_price   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     115.5
# Date:                Mon, 12 May 2025   Prob (F-statistic):          1.12e-164
# Time:                        16:32:50   Log-Likelihood:            -1.3699e+05
# No. Observations:               11917   AIC:                         2.740e+05
# Df Residuals:                   11909   BIC:                         2.740e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  1.075e+04   3102.015      3.465      0.001    4667.058    1.68e+04
# area_m2                3.236e-07   4.41e-07      0.733      0.463   -5.42e-07    1.19e-06
# avg_stars              3859.8458    883.555      4.369      0.000    2127.934    5591.758
# choice                -4968.5486    596.961     -8.323      0.000   -6138.689   -3798.408
# no_truck_length           0.0062      0.005      1.301      0.193      -0.003       0.016
# distance_pool          6.115e+05   6.79e+04      9.001      0.000    4.78e+05    7.45e+05
# foreclosure_count        -4.7441      1.620     -2.928      0.003      -7.920      -1.568
# foreclosure_over_area -1.103e+09   5.55e+07    -19.863      0.000   -1.21e+09   -9.95e+08
# ==============================================================================
# Omnibus:                    37124.160   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4204556126.909
# Skew:                          48.526   Prob(JB):                         0.00
# Kurtosis:                    2911.309   Cond. No.                     3.03e+14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.03e+14. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
iso_df[['id', 'distance', 'mode']] = iso_df['isochrone'].str.split('-', n=2, expand=True)
unique_combos = iso_df[['distance', 'mode']].drop_duplicates()

for dist, mode in unique_combos.values:
    subset = iso_df[(iso_df['distance'] == dist) & (iso_df['mode'] == mode)]
    model = run_regression(subset, features, target)
    print(f"Isochrone Regression: {dist}-{mode}")
    print(model.summary())
# Out:
# Isochrone Regression: 600-foot
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      avg_housing_price   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     7.008
# Date:                Mon, 12 May 2025   Prob (F-statistic):           3.19e-08
# Time:                        17:21:29   Log-Likelihood:                -16293.
# No. Observations:                1303   AIC:                         3.260e+04
# Df Residuals:                    1295   BIC:                         3.264e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                   6.72e+04   2.25e+04      2.992      0.003    2.31e+04    1.11e+05
# area_m2                  -0.0170      0.007     -2.304      0.021      -0.032      -0.003
# avg_stars              1333.4382   4460.130      0.299      0.765   -7416.433    1.01e+04
# choice                -4009.2743   5487.714     -0.731      0.465   -1.48e+04    6756.510
# no_truck_length          -0.4328      0.329     -1.314      0.189      -1.079       0.213
# distance_pool         -2.229e+05   3.86e+05     -0.577      0.564   -9.81e+05    5.35e+05
# foreclosure_count      1894.9943    895.229      2.117      0.034     138.736    3651.253
# foreclosure_over_area -5.626e+09   1.93e+09     -2.914      0.004   -9.41e+09   -1.84e+09
# ==============================================================================
# Omnibus:                     2923.269   Durbin-Watson:                   1.125
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11018507.827
# Skew:                          20.020   Prob(JB):                         0.00
# Kurtosis:                     451.717   Cond. No.                     2.20e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.2e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Isochrone Regression: 1200-foot
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      avg_housing_price   R-squared:                       0.517
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     202.0
# Date:                Mon, 12 May 2025   Prob (F-statistic):          1.08e-203
# Time:                        17:21:29   Log-Likelihood:                -13478.
# No. Observations:                1330   AIC:                         2.697e+04
# Df Residuals:                    1322   BIC:                         2.701e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  4411.5419   3043.671      1.449      0.147   -1559.410    1.04e+04
# area_m2                  -0.0004      0.000     -2.010      0.045      -0.001   -1.05e-05
# avg_stars              6335.1452    671.708      9.431      0.000    5017.416    7652.874
# choice                -6330.4535    447.042    -14.161      0.000   -7207.442   -5453.465
# no_truck_length          -0.0173      0.011     -1.535      0.125      -0.039       0.005
# distance_pool          3.662e+05    4.8e+04      7.632      0.000    2.72e+05     4.6e+05
# foreclosure_count        43.0981     31.395      1.373      0.170     -18.491     104.687
# foreclosure_over_area -1.393e+09   2.78e+08     -5.012      0.000   -1.94e+09   -8.48e+08
# ==============================================================================
# Omnibus:                     1144.294   Durbin-Watson:                   0.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            87145.933
# Skew:                           3.538   Prob(JB):                         0.00
# Kurtosis:                      42.019   Cond. No.                     1.43e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.43e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Isochrone Regression: 1800-foot
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      avg_housing_price   R-squared:                       0.643
# Model:                            OLS   Adj. R-squared:                  0.641
# Method:                 Least Squares   F-statistic:                     340.2
# Date:                Mon, 12 May 2025   Prob (F-statistic):          1.53e-290
# Time:                        17:21:29   Log-Likelihood:                -12987.
# No. Observations:                1332   AIC:                         2.599e+04
# Df Residuals:                    1324   BIC:                         2.603e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  9904.2471   2509.323      3.947      0.000    4981.565    1.48e+04
# area_m2                  -0.0001   8.17e-05     -1.754      0.080      -0.000    1.69e-05
# avg_stars              4642.0345    537.867      8.630      0.000    3586.870    5697.199
# choice                -4910.0332    283.541    -17.317      0.000   -5466.272   -4353.794
# no_truck_length          -0.0063      0.004     -1.453      0.147      -0.015       0.002
# distance_pool          3.345e+05   4.94e+04      6.775      0.000    2.38e+05    4.31e+05
# foreclosure_count        25.9021     12.834      2.018      0.044       0.724      51.080
# foreclosure_over_area -1.758e+09   2.54e+08     -6.916      0.000   -2.26e+09   -1.26e+09
# ==============================================================================
# Omnibus:                      152.354   Durbin-Watson:                   0.756
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              447.900
# Skew:                           0.586   Prob(JB):                     5.49e-98
# Kurtosis:                       5.588   Cond. No.                     4.44e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.44e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Isochrone Regression: 600-car
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      avg_housing_price   R-squared:                       0.791
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     1007.
# Date:                Mon, 12 May 2025   Prob (F-statistic):               0.00
# Time:                        17:21:29   Log-Likelihood:                -11843.
# No. Observations:                1336   AIC:                         2.370e+04
# Df Residuals:                    1330   BIC:                         2.373e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  2.396e+04   2077.988     11.531      0.000    1.99e+04     2.8e+04
# area_m2               -1.024e-05   3.29e-06     -3.115      0.002   -1.67e-05   -3.79e-06
# avg_stars              -602.5676    549.801     -1.096      0.273   -1681.139     476.004
# choice                -2342.9964    176.630    -13.265      0.000   -2689.500   -1996.493
# no_truck_length           0.0116      0.001     18.970      0.000       0.010       0.013
# distance_pool          5.989e-05   5.58e-06     10.731      0.000    4.89e-05    7.08e-05
# foreclosure_count        -2.0338      0.798     -2.550      0.011      -3.599      -0.469
# foreclosure_over_area  -1.76e+09   1.64e+08    -10.731      0.000   -2.08e+09   -1.44e+09
# ==============================================================================
# Omnibus:                       18.273   Durbin-Watson:                   0.725
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.708
# Skew:                           0.176   Prob(JB):                     7.11e-06
# Kurtosis:                       3.550   Cond. No.                     1.57e+26
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.5e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Isochrone Regression: 1200-car
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      avg_housing_price   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.938
# Method:                 Least Squares   F-statistic:                     4017.
# Date:                Mon, 12 May 2025   Prob (F-statistic):               0.00
# Time:                        17:21:30   Log-Likelihood:                -9503.7
# No. Observations:                1336   AIC:                         1.902e+04
# Df Residuals:                    1330   BIC:                         1.905e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  3.784e+04   1188.110     31.848      0.000    3.55e+04    4.02e+04
# area_m2               -1.492e-06   8.76e-08    -17.025      0.000   -1.66e-06   -1.32e-06
# avg_stars             -7904.5838    343.757    -22.995      0.000   -8578.949   -7230.218
# choice                 -139.9527     87.689     -1.596      0.111    -311.977      32.072
# no_truck_length           0.0180      0.000     99.124      0.000       0.018       0.018
# distance_pool         -9.592e-11   3.09e-12    -31.021      0.000   -1.02e-10   -8.99e-11
# foreclosure_count        -4.0560      0.050    -81.682      0.000      -4.153      -3.959
# foreclosure_over_area     0.0457      0.001     32.367      0.000       0.043       0.048
# ==============================================================================
# Omnibus:                      181.262   Durbin-Watson:                   0.947
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1265.468
# Skew:                           0.406   Prob(JB):                    1.61e-275
# Kurtosis:                       7.698   Cond. No.                     6.32e+27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.6e-35. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Isochrone Regression: 1800-car
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      avg_housing_price   R-squared:                       0.876
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     2341.
# Date:                Mon, 12 May 2025   Prob (F-statistic):               0.00
# Time:                        17:21:30   Log-Likelihood:                -7104.5
# No. Observations:                1336   AIC:                         1.422e+04
# Df Residuals:                    1331   BIC:                         1.425e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# area_m2                -9.44e-09   5.35e-09     -1.766      0.078   -1.99e-08    1.05e-09
# avg_stars             -7997.0129    549.585    -14.551      0.000   -9075.159   -6918.867
# choice                 4.133e+04   2096.514     19.714      0.000    3.72e+04    4.54e+04
# no_truck_length           0.0091      0.000     79.421      0.000       0.009       0.009
# distance_pool                  0          0        nan        nan           0           0
# foreclosure_count        -3.0475      0.042    -73.359      0.000      -3.129      -2.966
# foreclosure_over_area    -0.0841      0.004    -19.239      0.000      -0.093      -0.076
# ==============================================================================
# Omnibus:                      796.894   Durbin-Watson:                   1.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            43983.266
# Skew:                          -2.033   Prob(JB):                         0.00
# Kurtosis:                      30.813   Cond. No.                     6.28e+32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.78e-44. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Isochrone Regression: 600-pt
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      avg_housing_price   R-squared:                       0.119
# Model:                            OLS   Adj. R-squared:                  0.115
# Method:                 Least Squares   F-statistic:                     24.67
# Date:                Mon, 12 May 2025   Prob (F-statistic):           1.07e-31
# Time:                        17:21:30   Log-Likelihood:                -14901.
# No. Observations:                1282   AIC:                         2.982e+04
# Df Residuals:                    1274   BIC:                         2.986e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  3.308e+04   8144.532      4.061      0.000    1.71e+04    4.91e+04
# area_m2                  -0.0130      0.002     -6.243      0.000      -0.017      -0.009
# avg_stars              4608.0542   1998.229      2.306      0.021     687.873    8528.235
# choice                -2206.5181   2208.088     -0.999      0.318   -6538.406    2125.370
# no_truck_length          -0.1185      0.129     -0.921      0.357      -0.371       0.134
# distance_pool          2.641e+05   1.65e+05      1.603      0.109   -5.91e+04    5.87e+05
# foreclosure_count       890.4958    189.545      4.698      0.000     518.640    1262.351
# foreclosure_over_area -2.606e+09    3.7e+08     -7.052      0.000   -3.33e+09   -1.88e+09
# ==============================================================================
# Omnibus:                     2260.669   Durbin-Watson:                   1.792
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1607847.346
# Skew:                          12.100   Prob(JB):                         0.00
# Kurtosis:                     174.798   Cond. No.                     9.77e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.77e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Isochrone Regression: 1200-pt
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      avg_housing_price   R-squared:                       0.524
# Model:                            OLS   Adj. R-squared:                  0.522
# Method:                 Least Squares   F-statistic:                     208.2
# Date:                Mon, 12 May 2025   Prob (F-statistic):          3.03e-208
# Time:                        17:21:30   Log-Likelihood:                -13411.
# No. Observations:                1330   AIC:                         2.684e+04
# Df Residuals:                    1322   BIC:                         2.688e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  1.989e+04   2477.062      8.029      0.000     1.5e+04    2.47e+04
# area_m2                  -0.0003    7.7e-05     -3.779      0.000      -0.000      -0.000
# avg_stars              2090.1222    668.043      3.129      0.002     779.582    3400.662
# choice                -4451.4022    380.424    -11.701      0.000   -5197.703   -3705.101
# no_truck_length           0.0028      0.006      0.442      0.658      -0.010       0.015
# distance_pool          4.314e+05   6.67e+04      6.471      0.000    3.01e+05    5.62e+05
# foreclosure_count        30.7188      8.756      3.508      0.000      13.541      47.896
# foreclosure_over_area -1.508e+09    1.1e+08    -13.666      0.000   -1.72e+09   -1.29e+09
# ==============================================================================
# Omnibus:                     1808.028   Durbin-Watson:                   1.374
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           707548.679
# Skew:                           7.205   Prob(JB):                         0.00
# Kurtosis:                     115.072   Cond. No.                     9.98e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.98e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Isochrone Regression: 1800-pt
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      avg_housing_price   R-squared:                       0.806
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     783.4
# Date:                Mon, 12 May 2025   Prob (F-statistic):               0.00
# Time:                        17:21:30   Log-Likelihood:                -12232.
# No. Observations:                1332   AIC:                         2.448e+04
# Df Residuals:                    1324   BIC:                         2.452e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                   1.38e+04   1593.378      8.663      0.000    1.07e+04    1.69e+04
# area_m2                  -0.0001   1.33e-05    -10.083      0.000      -0.000      -0.000
# avg_stars              4021.1463    427.396      9.408      0.000    3182.700    4859.593
# choice                -5051.7615    223.392    -22.614      0.000   -5490.003   -4613.520
# no_truck_length           0.0085      0.001      7.429      0.000       0.006       0.011
# distance_pool          2.117e+05    7.5e+04      2.821      0.005    6.45e+04    3.59e+05
# foreclosure_count        12.1320      1.733      7.000      0.000       8.732      15.532
# foreclosure_over_area -1.607e+09   6.41e+07    -25.073      0.000   -1.73e+09   -1.48e+09
# ==============================================================================
# Omnibus:                      103.147   Durbin-Watson:                   0.800
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              415.795
# Skew:                          -0.256   Prob(JB):                     5.14e-91
# Kurtosis:                       5.689   Cond. No.                     4.98e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.98e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
price_lookup = df_census[['center','avg_housing_price']].rename(
    columns={'avg_housing_price':'census_price'}
)

iso_merged = iso_df.merge(price_lookup, on='center', how='left')

iso_merged = iso_merged.drop(columns=['avg_housing_price'])

iso_merged[['id','distance','m']] = (
    iso_merged['isochrone']
      .str.split('-', n=2, expand=True)
)

features = [
    'area_m2','avg_stars','choice',
    'no_truck_length','distance_pool',
    'foreclosure_count','foreclosure_over_area'
]
target = 'census_price'

def run_reg(df):
    df2 = df.dropna(subset=features + [target])
    X = df2[features].copy()
    X[['choice','no_truck_length']] = X[['choice','no_truck_length']].astype(int)
    X = sm.add_constant(X)
    y = df2[target]
    return sm.OLS(y, X).fit()

full_model = run_reg(iso_merged)
print("=== Full Isochrone Regression (census prices) ===")
print(full_model.summary())

combos = iso_merged[['distance','m']].drop_duplicates()

for dist, md in combos.values:
    sub = iso_merged[
        (iso_merged.distance==dist) &
        (iso_merged.m==md)
    ]
    m = run_reg(sub)
    print(f"\n=== Isochrone {dist}-{md} (census prices) ===")
    print(m.summary())
# Out:
# === Full Isochrone Regression (census prices) ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           census_price   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     358.7
# Date:                Mon, 12 May 2025   Prob (F-statistic):               0.00
# Time:                        20:39:04   Log-Likelihood:            -1.2340e+06
# No. Observations:              107118   AIC:                         2.468e+06
# Df Residuals:                  107110   BIC:                         2.468e+06
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  1.375e+04   1051.183     13.080      0.000    1.17e+04    1.58e+04
# area_m2                 1.63e-07   1.51e-07      1.079      0.280   -1.33e-07    4.59e-07
# avg_stars              1959.7430    299.558      6.542      0.000    1372.613    2546.872
# choice                -2572.5584    204.175    -12.600      0.000   -2972.738   -2172.378
# no_truck_length           0.0098      0.002      6.025      0.000       0.007       0.013
# distance_pool          2.049e+05   2.29e+04      8.957      0.000     1.6e+05     2.5e+05
# foreclosure_count        -4.8039      0.555     -8.657      0.000      -5.892      -3.716
# foreclosure_over_area -7.631e+08    1.9e+07    -40.183      0.000      -8e+08   -7.26e+08
# ==============================================================================
# Omnibus:                   327139.337   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      32898290303.465
# Skew:                          46.308   Prob(JB):                         0.00
# Kurtosis:                    2716.365   Cond. No.                     3.02e+14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.02e+14. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# === Isochrone 600-foot (census prices) ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           census_price   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     62.98
# Date:                Mon, 12 May 2025   Prob (F-statistic):           2.06e-89
# Time:                        20:39:04   Log-Likelihood:            -1.3549e+05
# No. Observations:               11768   AIC:                         2.710e+05
# Df Residuals:                   11760   BIC:                         2.711e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  2.729e+04   2716.039     10.048      0.000     2.2e+04    3.26e+04
# area_m2                  -0.0068      0.001     -7.608      0.000      -0.009      -0.005
# avg_stars              1222.9731    543.096      2.252      0.024     158.415    2287.531
# choice                -2745.1048    676.852     -4.056      0.000   -4071.846   -1418.363
# no_truck_length          -0.0502      0.041     -1.236      0.217      -0.130       0.029
# distance_pool          1.489e+05   4.68e+04      3.179      0.001    5.71e+04    2.41e+05
# foreclosure_count       650.4544    109.099      5.962      0.000     436.603     864.306
# foreclosure_over_area -1.834e+09   2.35e+08     -7.792      0.000    -2.3e+09   -1.37e+09
# ==============================================================================
# Omnibus:                    36310.376   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3829888787.286
# Skew:                          47.238   Prob(JB):                         0.00
# Kurtosis:                    2796.181   Cond. No.                     2.17e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.17e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# === Isochrone 1200-foot (census prices) ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           census_price   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     71.77
# Date:                Mon, 12 May 2025   Prob (F-statistic):          3.80e-102
# Time:                        20:39:05   Log-Likelihood:            -1.3754e+05
# No. Observations:               11949   AIC:                         2.751e+05
# Df Residuals:                   11941   BIC:                         2.752e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  2.668e+04   4034.266      6.613      0.000    1.88e+04    3.46e+04
# area_m2                  -0.0018      0.000     -6.447      0.000      -0.002      -0.001
# avg_stars              2830.5208    885.639      3.196      0.001    1094.525    4566.516
# choice                -2121.0319    589.175     -3.600      0.000   -3275.910    -966.154
# no_truck_length          -0.0196      0.015     -1.323      0.186      -0.049       0.009
# distance_pool          1.734e+04   6.41e+04      0.271      0.787   -1.08e+05    1.43e+05
# foreclosure_count       206.7720     41.437      4.990      0.000     125.550     287.994
# foreclosure_over_area -2.651e+09   3.67e+08     -7.224      0.000   -3.37e+09   -1.93e+09
# ==============================================================================
# Omnibus:                    36806.397   Durbin-Watson:                   1.943
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3863849452.416
# Skew:                          47.017   Prob(JB):                         0.00
# Kurtosis:                    2787.213   Cond. No.                     1.43e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.43e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# === Isochrone 1800-foot (census prices) ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           census_price   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     66.12
# Date:                Mon, 12 May 2025   Prob (F-statistic):           5.60e-94
# Time:                        20:39:05   Log-Likelihood:            -1.3773e+05
# No. Observations:               11964   AIC:                         2.755e+05
# Df Residuals:                   11956   BIC:                         2.755e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  2.278e+04   4842.719      4.705      0.000    1.33e+04    3.23e+04
# area_m2                  -0.0006      0.000     -4.122      0.000      -0.001      -0.000
# avg_stars              3484.9651   1039.367      3.353      0.001    1447.637    5522.293
# choice                -1831.1753    549.079     -3.335      0.001   -2907.459    -754.892
# no_truck_length          -0.0041      0.008     -0.493      0.622      -0.020       0.012
# distance_pool         -1.458e+04   9.75e+04     -0.150      0.881   -2.06e+05    1.77e+05
# foreclosure_count        76.1516     24.931      3.054      0.002      27.283     125.020
# foreclosure_over_area -2.653e+09   4.95e+08     -5.359      0.000   -3.62e+09   -1.68e+09
# ==============================================================================
# Omnibus:                    36865.608   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3868661377.897
# Skew:                          47.066   Prob(JB):                         0.00
# Kurtosis:                    2787.195   Cond. No.                     4.46e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.46e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# === Isochrone 600-car (census prices) ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           census_price   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     63.10
# Date:                Mon, 12 May 2025   Prob (F-statistic):           3.47e-65
# Time:                        20:39:05   Log-Likelihood:            -1.3780e+05
# No. Observations:               11964   AIC:                         2.756e+05
# Df Residuals:                   11958   BIC:                         2.757e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                 -7911.5845   9969.986     -0.794      0.427   -2.75e+04    1.16e+04
# area_m2               -1.595e-05    1.6e-05     -1.000      0.317   -4.72e-05    1.53e-05
# avg_stars              1.066e+04   2624.209      4.061      0.000    5512.072    1.58e+04
# choice                -4436.9209    842.424     -5.267      0.000   -6088.209   -2785.633
# no_truck_length           0.0002      0.003      0.072      0.943      -0.005       0.006
# distance_pool         -9.556e-06   1.78e-06     -5.373      0.000    -1.3e-05   -6.07e-06
# foreclosure_count         9.6536      3.846      2.510      0.012       2.115      17.192
# foreclosure_over_area -4.271e+09   7.95e+08     -5.373      0.000   -5.83e+09   -2.71e+09
# ==============================================================================
# Omnibus:                    36738.004   Durbin-Watson:                   1.918
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3744109574.570
# Skew:                          46.617   Prob(JB):                         0.00
# Kurtosis:                    2741.989   Cond. No.                     2.22e+27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.13e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# === Isochrone 1200-car (census prices) ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           census_price   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     51.53
# Date:                Mon, 12 May 2025   Prob (F-statistic):           4.75e-53
# Time:                        20:39:05   Log-Likelihood:            -1.3783e+05
# No. Observations:               11964   AIC:                         2.757e+05
# Df Residuals:                   11958   BIC:                         2.757e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  3.059e+05   3.26e+04      9.383      0.000    2.42e+05     3.7e+05
# area_m2                1.043e-06    2.4e-06      0.434      0.664   -3.67e-06    5.75e-06
# avg_stars             -8.123e+04   9431.434     -8.613      0.000   -9.97e+04   -6.27e+04
# choice                 1.457e+04   2402.108      6.066      0.000    9861.788    1.93e+04
# no_truck_length           0.0015      0.005      0.304      0.761      -0.008       0.011
# distance_pool         -9.318e-10   9.99e-11     -9.325      0.000   -1.13e-09   -7.36e-10
# foreclosure_count        -5.5973      1.362     -4.108      0.000      -8.268      -2.927
# foreclosure_over_area     0.3555      0.038      9.425      0.000       0.282       0.429
# ==============================================================================
# Omnibus:                    36638.656   Durbin-Watson:                   1.907
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3680118177.056
# Skew:                          46.264   Prob(JB):                         0.00
# Kurtosis:                    2718.478   Cond. No.                     5.33e+28
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.81e-36. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# === Isochrone 1800-car (census prices) ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           census_price   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     63.42
# Date:                Mon, 12 May 2025   Prob (F-statistic):           3.84e-53
# Time:                        20:39:05   Log-Likelihood:            -1.3783e+05
# No. Observations:               11964   AIC:                         2.757e+05
# Df Residuals:                   11959   BIC:                         2.757e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# area_m2               -1.087e-06   8.83e-07     -1.231      0.218   -2.82e-06    6.43e-07
# avg_stars               8.99e+05    9.1e+04      9.878      0.000    7.21e+05    1.08e+06
# choice                -3.341e+06   3.47e+05     -9.625      0.000   -4.02e+06   -2.66e+06
# no_truck_length           0.1815      0.019      9.532      0.000       0.144       0.219
# distance_pool          3.842e-10   3.98e-11      9.641      0.000    3.06e-10    4.62e-10
# foreclosure_count       -24.5475      6.909     -3.553      0.000     -38.091     -11.004
# foreclosure_over_area     6.5334      0.677      9.649      0.000       5.206       7.861
# ==============================================================================
# Omnibus:                    36633.844   Durbin-Watson:                   1.906
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3670478502.586
# Skew:                          46.248   Prob(JB):                         0.00
# Kurtosis:                    2714.916   Cond. No.                     6.33e+31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.33e-41. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# === Isochrone 600-pt (census prices) ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           census_price   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     53.94
# Date:                Mon, 12 May 2025   Prob (F-statistic):           2.83e-76
# Time:                        20:39:05   Log-Likelihood:            -1.3403e+05
# No. Observations:               11634   AIC:                         2.681e+05
# Df Residuals:                   11626   BIC:                         2.681e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  1.725e+04   2374.721      7.265      0.000    1.26e+04    2.19e+04
# area_m2                  -0.0026      0.001     -4.255      0.000      -0.004      -0.001
# avg_stars              1514.4512    589.576      2.569      0.010     358.783    2670.119
# choice                -2141.9984    661.927     -3.236      0.001   -3439.487    -844.510
# no_truck_length          -0.0468      0.039     -1.214      0.225      -0.122       0.029
# distance_pool          2.222e+05   4.83e+04      4.605      0.000    1.28e+05    3.17e+05
# foreclosure_count       180.4371     55.539      3.249      0.001      71.571     289.304
# foreclosure_over_area -8.119e+08   1.08e+08     -7.520      0.000   -1.02e+09      -6e+08
# ==============================================================================
# Omnibus:                    35815.187   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3680873269.342
# Skew:                          46.940   Prob(JB):                         0.00
# Kurtosis:                    2757.003   Cond. No.                     9.51e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.51e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# === Isochrone 1200-pt (census prices) ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           census_price   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     63.74
# Date:                Mon, 12 May 2025   Prob (F-statistic):           1.57e-90
# Time:                        20:39:05   Log-Likelihood:            -1.3758e+05
# No. Observations:               11950   AIC:                         2.752e+05
# Df Residuals:                   11942   BIC:                         2.752e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  1.498e+04   3446.907      4.346      0.000    8223.068    2.17e+04
# area_m2               -9.637e-05      0.000     -0.899      0.369      -0.000       0.000
# avg_stars              2681.7332    929.325      2.886      0.004     860.106    4503.361
# choice                -2266.3959    528.505     -4.288      0.000   -3302.351   -1230.441
# no_truck_length           0.0014      0.009      0.157      0.875      -0.016       0.019
# distance_pool          1.594e+05   9.37e+04      1.702      0.089   -2.42e+04    3.43e+05
# foreclosure_count        17.2271     12.203      1.412      0.158      -6.694      41.148
# foreclosure_over_area  -1.28e+09   1.54e+08     -8.306      0.000   -1.58e+09   -9.78e+08
# ==============================================================================
# Omnibus:                    36815.082   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3850641527.311
# Skew:                          47.041   Prob(JB):                         0.00
# Kurtosis:                    2782.326   Cond. No.                     1.00e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  1e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# === Isochrone 1800-pt (census prices) ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           census_price   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     56.79
# Date:                Mon, 12 May 2025   Prob (F-statistic):           1.87e-80
# Time:                        20:39:05   Log-Likelihood:            -1.3773e+05
# No. Observations:               11961   AIC:                         2.755e+05
# Df Residuals:                   11953   BIC:                         2.755e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  7738.3026   5473.415      1.414      0.157   -2990.480    1.85e+04
# area_m2                  -0.0002   4.56e-05     -5.266      0.000      -0.000      -0.000
# avg_stars              7219.4419   1468.850      4.915      0.000    4340.258    1.01e+04
# choice                -4465.5067    765.932     -5.830      0.000   -5966.859   -2964.155
# no_truck_length          -0.0010      0.004     -0.254      0.799      -0.009       0.007
# distance_pool         -3.742e+05   2.54e+05     -1.475      0.140   -8.72e+05    1.23e+05
# foreclosure_count        36.2163      5.951      6.085      0.000      24.551      47.882
# foreclosure_over_area -2.514e+09   2.21e+08    -11.388      0.000   -2.95e+09   -2.08e+09
# ==============================================================================
# Omnibus:                    36786.504   Durbin-Watson:                   1.928
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3799596395.577
# Skew:                          46.819   Prob(JB):                         0.00
# Kurtosis:                    2762.566   Cond. No.                     5.01e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.01e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
